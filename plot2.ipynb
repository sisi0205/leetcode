# %%
import matplotlib.pyplot as plt
import numpy as np

Y=[0.1723,0.0293,0.2852]
X=["KNN","MFA","L+"]


plt.figure(1)
x = range(3)
plt.xlim([-0.5,2.5])
plt.xticks(x, X)
plt.plot(x,Y,"g")

plt.xlabel("Scoring method")
###(The proportion of products from the test set that appear among the top 20 of the recommendation list)
plt.ylabel("Recal 20 ")
plt.show()
