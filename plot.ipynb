# %%
import matplotlib.pyplot as plt
import numpy as np

Y=[0.0006,0.2447,0.2165,0.1910,0.1723]
X=[1,10,20,50,100]
plt.ylim([0,0.3])
plt.xlabel("K (k nearest neighbors of product for a person)")
###(The proportion of products from the test set that appear among the top 20 of the recommendation list)
plt.ylabel("Recal 20 ")
plt.plot(X,Y)
plt.show()
